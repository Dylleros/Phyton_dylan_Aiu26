# %%
firstname = input ("What is your firstname?")
lastname = input ("What is your lastname?")

print (f"Hello your name is {firstname} {lastname}")
# Out:
# Hello your name is Dylan Pathirana

# %%
name = "Dylan"
age = 31

print (f"Hello {name}, you are {age} years old")
# Out:
# Hello Dylan, you are 31 years old
